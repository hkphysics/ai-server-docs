# %%
# %load_ext jupyter_ai_magic_commands

# %%
# %%ai @Jupyternaut -m '{"model_id": "ollama_chat/hf.co/deepreinforce-ai/Ornith-1.0-35B-GGUF:latest", "model_args": {"persistence":"false", "api_base": "http://ollama:11434"}}' --eval
#
# text = """
# # What do I use jupyter for
#
# I am finding that jupyter is useful as a scientific desktop.  So in the old days
# I would have a desk with a bunch of papers and a blackboard.  Jupyter works nicely
# not just as a compute engine but a physicist office.  The key nice thing about Jupyter
# is that with a virtual office, I can work remotely, which turns out to be very useful
# in working with conferences or in transit.
#
# # What is AI useful for?
# * Reducing friction. For example in writing this markdown file, it would be useful to
#   * Do a literature search for content
#   * Upload this to my substack
#   * Connect this with the conversation on github
#   * Store the notes so that I can get a conference paper out of this
#   * Multilingual situations. For example, Chinese physicists will communicate in English, but
#     Chinese manufacturers will use Chinese.  AI is incredibly useful for cross-linguistic teams.
#
# # Notes on personas
#
# What is a persona?  A persona is personality that you interact.  It is different
# from an agent since the agent is the role, whereas the persona is the personality.
# Think of a doorman.  The role (agent) is the doorman, but to be an effective doorman
# the person has skills and a life outside of being a doorman.  Think of Fred the doorman,
# the doorman is the agent role, but Fred is the persona.
#
# Also personas should be able to easily connect to other agents.
#
# # Personas should be easily customizable
# * You should be able to take a persona and then easily convert it into a different persona
# * You should be able to override the parameters for a specific message
# * You should be able to take a persona with parameters and convert to a new persona and publish
#
# # What parameters exist for personas
# * Model to connect to
# * Instance of the model
# * Permissions to connect
# * Model parameters
# * System prompt
# * What memory/context should it read from
# * What memory/context should it write to
#
# Note that missing from this list are SKILLs since skills belong more in the agent than in the
#
# # Messages
# There are several different message protocols
# * Jupyter kernel messages
# * OpenAI messages
# * Jupyter AI messages
# * MCP
# * ACP
#
# The messages should be interchangable and there should be easy conversation from one type of message to another
#
# # Memory/context
#
# The second element is memory/context.  YChat is one form of memory/context. There are also various locations where memory/context is stored.  In SQLlite memory in Jupyter. In the agent,  Various locations in the agent.  As with agent, there should be an effort to make sure that memory/context is underchangable.
#
# """
#
# """Convert this to a substack post by expanding the ideas into prose""" + text

# %%
# %%ai @Jupyternaut -m '{"model_id": "ollama_chat/hf.co/deepreinforce-ai/Ornith-1.0-35B-GGUF:latest", "model_args": {"persistence":"false", "api_base": "http://ollama:11434"}}' --eval
#
# """Convert this to a powerpoint pdf""" + text
